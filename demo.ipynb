# %%
from web3 import Web3
import json
import requests
import pandas as pd
from PeepethClient import PeepethClient
from dotenv import load_dotenv
import os

load_dotenv()
web3url = os.getenv("web3url")

contract_abi_path = "peepeth_abi.json"
contract_adr = "0xfa28eC7198028438514b49a3CF353BcA5541ce1d"

client_example = PeepethClient(web3url, contract_adr, contract_abi_path, 20000)

# %%
data = client_example.refresh()

# %%
print([''])
# Out:
# [{'type': 'peep',
#   'content': 'BITCOIN: BIG NEWS!! MILLIONS of Investors BRAND NEW ACCESS to BTC! $3.8k FIRST?! https://www.youtube.com/watch?v=anxHv9oumzE',
#   'pics': [],
#   'untrustedAddress': '0x926e54f7a2ecc16151bb87be2bac37d8dcb637e3',
#   'untrustedTimestamp': 1586628738,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': 'Thank you Bevan!',
#   'pics': [],
#   'untrustedAddress': '0x04a5f69437120514d9c4e7a0757898960b0eab46',
#   'untrustedTimestamp': 1562754774,
#   'shareID': '',
#   'parentID': 'QmRxEZCTiJ8x9RUy6vW1Sh25mgoXfjkKDfA6JJ97U8kbHY'},
#  {'type': 'peep',
#   'content': '#lisp #treasure',
#   'pics': ['QmP1xYL9W5rEn4XspCCN7NU6DE1AWevTZ4bMyHAiZVCmcJ'],
#   'untrustedAddress': '0x04a5f69437120514d9c4e7a0757898960b0eab46',
#   'untrustedTimestamp': 1564859397,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': '"Re-examine all you have been told, and dismiss whatever insults your own soul." - Whitman',
#   'pics': [],
#   'untrustedAddress': '0x04a5f69437120514d9c4e7a0757898960b0eab46',
#   'untrustedTimestamp': 1570024712,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': "If you're a Coinbase user and willing to watch a few short videos about Orchid, you can use this link to earn us both some OXT. It's an interesting idea, an ETH-token-driven VPN. https://coinbase.com/earn/oxt/invite/m6qb3sn8",
#   'pics': [],
#   'untrustedAddress': '0x04a5f69437120514d9c4e7a0757898960b0eab46',
#   'untrustedTimestamp': 1582484861,
#   'shareID': '',
#   'parentID': ''},
#  {'followee': '0x86f282a3e3ffb05702e49d17b782214ed2751ca2',
#   'untrustedTimestamp': 1582485811},
#  {'type': 'peep',
#   'content': 'thank you for this',
#   'pics': [],
#   'untrustedAddress': '0x04a5f69437120514d9c4e7a0757898960b0eab46',
#   'untrustedTimestamp': 1582485860,
#   'shareID': '',
#   'parentID': 'QmQP7NoxSA7i9wM2PvsFkKfPnQJkA33dksKSBYGXntGGMg'},
#  {'type': 'peep',
#   'content': 'Band-Maid forever though https://www.youtube.com/watch?v=Uds7g3M-4lQ',
#   'pics': [],
#   'untrustedAddress': '0x04a5f69437120514d9c4e7a0757898960b0eab46',
#   'untrustedTimestamp': 1582486395,
#   'shareID': '',
#   'parentID': 'QmSfHkahyvBEBqiPXCkKyUfg1p6goTQZWCZyKyxqtJHJSb'},
#  {'followee': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1582486824},
#  {'type': 'peep',
#   'content': 'The growler was the best part of the song, no question.',
#   'pics': [],
#   'untrustedAddress': '0x04a5f69437120514d9c4e7a0757898960b0eab46',
#   'untrustedTimestamp': 1582492605,
#   'shareID': '',
#   'parentID': 'QmTNVssruTw1sKzDVzmrCumd9uhkqBba8nuCDagwVgHKKx'},
#  {'type': 'peep',
#   'content': 'And here I was just plugging this <shruggie/>',
#   'pics': [],
#   'untrustedAddress': '0x04a5f69437120514d9c4e7a0757898960b0eab46',
#   'untrustedTimestamp': 1582553840,
#   'shareID': '',
#   'parentID': 'QmP1wy1YDTcj55oyR9mfvUSLFRYxgTonr581nxNseYFnUf'},
#  {'type': 'peep',
#   'content': '"Our wretched species is so made that those who walk on the well-trodden path always throw stones at those who are showing a new road." - Voltaire',
#   'pics': [],
#   'untrustedAddress': '0x04a5f69437120514d9c4e7a0757898960b0eab46',
#   'untrustedTimestamp': 1586628507,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': "Hey, peeps. It's been a while.",
#   'pics': [],
#   'untrustedAddress': '0x04a5f69437120514d9c4e7a0757898960b0eab46',
#   'untrustedTimestamp': 1586628540,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': '降伏と犠牲。',
#   'pic': 'QmXkoVXMh5dNF9xQhqkqv5bz4y9R1ncT4DjcSvLFJb2rSc',
#   'untrustedAddress': '0x7e9318be142723a75635de754432a4a11ac42120',
#   'untrustedTimestamp': 1586642016,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': '心による支配の自由',
#   'pic': 'QmZ5644ZfZephGWtRntWDAiNWFh6tpJJdC89PUv4vVTktT',
#   'untrustedAddress': '0x7e9318be142723a75635de754432a4a11ac42120',
#   'untrustedTimestamp': 1586642103,
#   'shareID': '',
#   'parentID': ''},
#  {'info': '',
#   'location': '',
#   'realName': 'Spiderman',
#   'website': '',
#   'avatarUrl': 'peepeth:aVzaAXAq:jpg',
#   'backgroundUrl': 'peepeth:4u94QB8j:jpg',
#   'messageToWorld': '',
#   'untrustedTimestamp': 1586644010,
#   'provisionalName': 'Spidey',
#   'address': '0xebc9758f2f1775c37c1ee135be6daf7e3a291a6a'},
#  {'type': 'peep',
#   'content': '',
#   'pics': ['QmS2gFXxSNkuGZHeVci7DbQZjoP2phnXmJcP3AgobJCvEm'],
#   'untrustedAddress': '0x9b74c8ac5d9c13836e677d0c279e7f038417724b',
#   'untrustedTimestamp': 1586665367,
#   'shareID': '',
#   'parentID': ''},
#  {'info': 'Mechanical Engineer. Lifelong Madridista, Tv series and Movie lover. Football all the way    ',
#   'location': 'Chittagong ',
#   'realName': 'Nur Uddin Nishad ',
#   'website': 'www.facebook.com/nishad.coproton',
#   'avatarUrl': '',
#   'backgroundUrl': '',
#   'messageToWorld': 'Live Free',
#   'untrustedTimestamp': 1586670647,
#   'provisionalName': 'coproton',
#   'address': '0x4607514f0551799f9184969a0c7347265c0c0e3a'},
#  {'info': '',
#   'location': 'Singapore',
#   'realName': 'Shohei Kamon',
#   'website': 'https://stir.network',
#   'avatarUrl': '',
#   'backgroundUrl': '',
#   'messageToWorld': '',
#   'untrustedTimestamp': 1586674211,
#   'provisionalName': 'cameong',
#   'address': '0x95340b69162d21a931da57cb9759b671ef57ee7f'},
#  {'type': 'peep',
#   'content': '👍',
#   'pics': [],
#   'untrustedAddress': '0xa7bd09daab3eb5ec96f04914d94c47681489d604',
#   'untrustedTimestamp': 1586675068,
#   'shareID': '',
#   'parentID': 'QmTopdD3XqoHgDHcKmkJSsu59r7g48PVGkakXf9EfEy4cz'},
#  {'type': 'peep',
#   'content': '👋',
#   'pics': [],
#   'untrustedAddress': '0xa7bd09daab3eb5ec96f04914d94c47681489d604',
#   'untrustedTimestamp': 1586675087,
#   'shareID': '',
#   'parentID': 'QmcqYixDmaJnpRbp2e22jhsbep7JdjCWp8tEFirLHW8gLa'},
#  {'type': 'peep',
#   'content': 'Nope. What are we looking at?',
#   'pics': [],
#   'untrustedAddress': '0xa7bd09daab3eb5ec96f04914d94c47681489d604',
#   'untrustedTimestamp': 1586675229,
#   'shareID': '',
#   'parentID': 'QmYYUNHzPDzipPu4TRkECkGkmVJZqjydkWNUmo89fWxiRo'},
#  {'type': 'peep',
#   'content': 'Here is good! 😃',
#   'pics': [],
#   'untrustedAddress': '0xa7bd09daab3eb5ec96f04914d94c47681489d604',
#   'untrustedTimestamp': 1586675297,
#   'shareID': '',
#   'parentID': 'QmeBdZgnFZ94w9pymZPPtjtba4hgeAwSYpyyuRdsHhPpHg'},
#  {'info': '',
#   'location': '',
#   'realName': '',
#   'website': '',
#   'avatarUrl': '',
#   'backgroundUrl': '',
#   'messageToWorld': '',
#   'untrustedTimestamp': 1586676940,
#   'provisionalName': 'abbaskiko',
#   'address': '0x02f92b52b6eb06f19a15f0d957ff7282707cf8a6'},
#  {'type': 'peep',
#   'content': 'Have you ever wondered what are Exchange Utility Tokens? Learn more about them in my latest blog-post.\n\nhttps://www.uptrennd.com/post-detail/what-are-exchange-utility-tokens~MjczNDAz',
#   'pics': ['QmV7QL5LUcURNbPLHuxWTfbxdeBfCc8hyvt5bzuX4oY8Ng'],
#   'untrustedAddress': '0x00f33c3bce1b479bc7ffacc986badced8b2d7cad',
#   'untrustedTimestamp': 1586433864,
#   'shareID': '',
#   'parentID': ''},
#  {'info': '',
#   'location': '',
#   'realName': 'esportsedu',
#   'website': 'esportsedu.github.io',
#   'avatarUrl': 'peepeth:drS8Na9A:png',
#   'backgroundUrl': 'peepeth:fLB2ce4c:jpg',
#   'messageToWorld': '',
#   'untrustedTimestamp': 1586690596,
#   'provisionalName': 'esportsedu',
#   'address': '0xd6e70293c4f5a4b54961704e68d15beede25b473'},
#  {'type': 'peep',
#   'content': 'Hey Shohei, welcome to Peepeth 👋',
#   'pics': [],
#   'untrustedAddress': '0x9b74c8ac5d9c13836e677d0c279e7f038417724b',
#   'untrustedTimestamp': 1586696577,
#   'shareID': '',
#   'parentID': 'QmcqYixDmaJnpRbp2e22jhsbep7JdjCWp8tEFirLHW8gLa'},
#  {'type': 'peep',
#   'content': '',
#   'pics': [],
#   'untrustedAddress': '0x30755d3e65c0cf46c35b72d11e52d941c5fc3a3e',
#   'untrustedTimestamp': 1586352583,
#   'shareID': 'QmdWhYgVGpgALrVNJyKpFkSwZAfnBGGgRYbFdza7JtApre',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': '#lkie',
#   'pics': [],
#   'untrustedAddress': '0x30755d3e65c0cf46c35b72d11e52d941c5fc3a3e',
#   'untrustedTimestamp': 1586440905,
#   'shareID': '',
#   'parentID': 'QmR4769nWNMxoaVEUXUYyvD9vmzUjYuCXdHRamsg4wSQwd'},
#  {'type': 'peep',
#   'content': "I hear you. The secondary effects are certainly real.\n\nHope you can get outside soon. That's been my saving grace.",
#   'pics': [],
#   'untrustedAddress': '0x30755d3e65c0cf46c35b72d11e52d941c5fc3a3e',
#   'untrustedTimestamp': 1586486044,
#   'shareID': '',
#   'parentID': 'QmSujyGAeWw1Ao8968sQDocTT4ezocGwWyKUxE3skT3P6t'},
#  {'type': 'peep',
#   'content': '@abcoathup Spotted some cousins of your crypto horses:\n\nhttps://opensea.io/accounts/0xdacc61c3f6992659f7293ad4bb67ed54c66f2665',
#   'pics': [],
#   'untrustedAddress': '0x30755d3e65c0cf46c35b72d11e52d941c5fc3a3e',
#   'untrustedTimestamp': 1586486112,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': "“All of humanity's problems stem from man's inability to sit quietly in a room alone.”\n\n― Blaise Pascal",
#   'pics': [],
#   'untrustedAddress': '0x30755d3e65c0cf46c35b72d11e52d941c5fc3a3e',
#   'untrustedTimestamp': 1586579436,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': '',
#   'pics': [],
#   'untrustedAddress': '0x30755d3e65c0cf46c35b72d11e52d941c5fc3a3e',
#   'untrustedTimestamp': 1586579450,
#   'shareID': 'QmVcXRVKv6fLgUzcVuamnLUzJRxAN8E6rdPe6FByUNQwRf',
#   'parentID': ''},
#  {'messageID': 'QmVcXRVKv6fLgUzcVuamnLUzJRxAN8E6rdPe6FByUNQwRf',
#   'untrustedTimestamp': 1586579454},
#  {'type': 'peep',
#   'content': '3.5 hours, sounds like it went well.',
#   'pics': [],
#   'untrustedAddress': '0x30755d3e65c0cf46c35b72d11e52d941c5fc3a3e',
#   'untrustedTimestamp': 1586638839,
#   'shareID': '',
#   'parentID': 'QmcVhWB5VLwQtgpFy4dLKsVWvFjAcfaviTGkMrDAGy9eUQ'},
#  {'type': 'peep',
#   'content': 'Happy Easter 🐣',
#   'pics': [],
#   'untrustedAddress': '0x30755d3e65c0cf46c35b72d11e52d941c5fc3a3e',
#   'untrustedTimestamp': 1586706339,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': 'Your president is an ass. Your entire system is corrupt. Your foreign policy is openly hostile. But you want sympathy??',
#   'pics': [],
#   'untrustedAddress': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1586556398,
#   'shareID': '',
#   'parentID': 'QmYBm6oeHXfmHZLqrXW9rZcAcRh7LGVfHFLu4QLLt8QAKr'},
#  {'type': 'peep',
#   'content': '1/ Every day recently has seen a new low from him. Trying to buy up German vaccine companies for "Americans only", stealing medical equipment meant for other countries (France, Canada, Barbados & others), blocking medical supplies meant for Iran, the constant China-bashing ',
#   'pics': [],
#   'untrustedAddress': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1586603663,
#   'shareID': '',
#   'parentID': 'QmVpqBka8cqDxpTXR61M4M9yyrDgr6B3ZpAeXgrcUXgaYR'},
#  {'type': 'peep',
#   'content': "2/ and trying to start a war with Venezuela. \n\nBut yes, it is the poor and vulnerable who will suffer the most. What's happening in New York is downright scary and it could get a lot worse. ",
#   'pics': [],
#   'untrustedAddress': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1586603734,
#   'shareID': '',
#   'parentID': 'QmRqXNZDqRkRko9eGi28rAm8sFiV3qLcMDM4ZCkzDHy9q2'},
#  {'type': 'peep',
#   'content': "3/ I don't understand how the so-called richest countries in the world can't look after people. Putin a few weeks ago just paid all workers for April. Whatever you were earning, you got. No fuss or fanfare, just done. The US and UK would prefer people starve or got into debt. ",
#   'pics': [],
#   'untrustedAddress': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1586603844,
#   'shareID': '',
#   'parentID': 'QmWtmMNnX7Ayye92YAfHdtWM7EXQMFvjdagWswUD2QRNxh'},
#  {'type': 'peep',
#   'content': '4/ The same with healthcare. Something like $40k average bill for covid-19 treatment in the US??! How is anyone out of work supposed to be able to pay for that? ',
#   'pics': [],
#   'untrustedAddress': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1586603873,
#   'shareID': '',
#   'parentID': 'QmUpQcF5fWDYPhSU8fGyQL7AK5uUnhZ657fdjH5FhjEre4'},
#  {'type': 'peep',
#   'content': '5/ Afaik, about 8 or 9 states have no lockdown at the moment and some states have said Easter religious services can go ahead. That is complete lunacy. If that happens, expect to see a large spike in cases in about 2 weeks...  ',
#   'pics': [],
#   'untrustedAddress': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1586603920,
#   'shareID': '',
#   'parentID': 'QmX7begsrKGXJBmuqrC55FAFdT4KAYvBPypKNUk1ws3hC8'},
#  {'type': 'peep',
#   'content': "I actually start to wonder if he's just gone insane. It's just constant lies and misinformation, but at a cost of people's lives. The amount of conspiracy theories floating around his supporters is at dangerous levels. \n The way he treats the press is disgusting. ",
#   'pics': [],
#   'untrustedAddress': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1586604936,
#   'shareID': '',
#   'parentID': 'QmQMHBVxYrbSb7M9rXM4mW5eWNJwKoXkwXDwT3PVHCynKU'},
#  {'type': 'peep',
#   'content': 'I saw a news report the other day of a sick man getting hooked up to a ventilator and his only thought was "who\'s going to pay for this?"\nIt\'s just sad. Plenty of countries can manage free healthcare, you\'d think it would be a priority at a time like this. ',
#   'pics': [],
#   'untrustedAddress': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1586605179,
#   'shareID': '',
#   'parentID': 'QmV8Crgar1dxYN8S1e8yJZ4K1HC8qvyrjZiFj9LYyHwGwr'},
#  {'type': 'peep',
#   'content': "Agreed. I thought he was the lesser of 2 evils in 2016 but maybe he wasn't. No respect for American people, any other country or even international laws. ",
#   'pics': [],
#   'untrustedAddress': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1586605473,
#   'shareID': '',
#   'parentID': 'QmXuhave72bDcvu1Tej3T3jwvXhmvwoC1RxnvjdQsN3BcD'},
#  {'type': 'peep',
#   'content': "A routine illness shouldn't mean someone goes bankrupt. Nobody chooses to get ill. The for-profit model needs to be abolished - everywhere. \nI'm lucky. I have (mostly) free healthcare and EU-wide cover in case of accident when travelling, etc. ",
#   'pics': [],
#   'untrustedAddress': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1586605810,
#   'shareID': '',
#   'parentID': 'QmTg5QW4qGcAyUH1y7BdJD81CkHir6PKPqZKvz3ed6bQ7U'},
#  {'type': 'peep',
#   'content': "Sadly, I think it's already died in the US although other countries still have some form of democracy.\n\nEver think it's strange that most countries can have elections with minimal fuss but the US needs a 2-year media circus? ",
#   'pics': [],
#   'untrustedAddress': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1586606136,
#   'shareID': '',
#   'parentID': 'QmZpkZeNtHGpVPjx6hxus5UaQg9WtZqJHzzoxiUPb9KU97'},
#  {'type': 'peep',
#   'content': 'But of course. They protect themselves & take handouts from the pharma companies while the average person is left to die.\nIt would be so easy to extend that free healthcare to the rest of the population. But no financial incentive for them... 😕',
#   'pics': [],
#   'untrustedAddress': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1586606514,
#   'shareID': '',
#   'parentID': 'QmRGqo4y3CnTSYJtQ9pzGevzJMyCuqwk5nWp7yZkpqsvqz'},
#  {'type': 'peep',
#   'content': 'And you. Good chat! 😉',
#   'pics': [],
#   'untrustedAddress': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1586606867,
#   'shareID': '',
#   'parentID': 'QmQacpKkWjBE4BoZgshfqvyiHUb9uFCQeYDPdjgVgxVqjb'},
#  {'type': 'peep',
#   'content': "German President Steinmeier : Coronavirus a 'test of our humanity' \nhttps://youtu.be/wpaiUK9j6RM\n",
#   'pics': [],
#   'untrustedAddress': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1586709863,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': 'Already got mine 😉',
#   'pics': [],
#   'untrustedAddress': '0x1d6776f6cfb5804724c71d98009acfc3ec564ec8',
#   'untrustedTimestamp': 1586709963,
#   'shareID': '',
#   'parentID': 'QmbVHkFZfBNR1T1V4zzPdtopcmYVQJjvrPu3dFwVfx4a54'},
#  {'info': 'I am an Artist, a singer and Entertainer, I love the Crypto world',
#   'location': 'Riverstate Nigeria ',
#   'realName': 'Franklyn Ebuka ',
#   'website': '',
#   'avatarUrl': '',
#   'backgroundUrl': '',
#   'messageToWorld': 'Crypto world and blood, here I come, Am an Alien to this I need enlightment ',
#   'untrustedTimestamp': 1586709954,
#   'provisionalName': 'Hkayoriginalle',
#   'address': '0x86176126694c14c6983187fcab0d9fe20bf98285'},
#  {'info': 'Earn lots of ETH with only 0.51 ETH.',
#   'location': 'VIET NAM',
#   'realName': 'NGUYEN PHU NHO',
#   'website': 'https://nguyenphunho.github.io',
#   'avatarUrl': 'peepeth:ciFCVS92:png',
#   'backgroundUrl': 'peepeth:3PpidQ2j:png',
#   'messageToWorld': 'Earn lots of ETH with only 0.51 ETH.',
#   'untrustedTimestamp': 1586718654,
#   'provisionalName': 'NGUYENPHUNHO',
#   'address': '0x95d53611fe737abc5f810a5900208242d29645df'},
#  {'followee': '0x1db3439a222c519ab44bb1144fc28167b4fa6ee6',
#   'untrustedTimestamp': 1586718734},
#  {'type': 'peep',
#   'content': ' Earn lots of ETH with only 0.51 ETH.\n\n Website: https://nguyenphnho.github.io\n\n Dapp Sign Up: https://oneclickdapp.com/short-oxygen\n Dapp radar: https://dappradar.com/app/1843\n Dapp Review: https://dapp.review/dapp/12733\n Dapp Online: https://dapponline.io/dapp-detail/3445',
#   'pics': ['QmcoERHwGsjscaunyxwwYDPDZ5jHG264V9jpbKid66iPTi'],
#   'untrustedAddress': '0x95d53611fe737abc5f810a5900208242d29645df',
#   'untrustedTimestamp': 1586719132,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': 'Earn free $ 50,000 / month with Brave.\n\n1. Download the Brave browser: https://brave.com/irx228\n2. Create Payment Brave account: https://publishers.basicattentiontoken.org\n3. Create and KYC Uphold account & link with Payment Brave account to receive BAT: https://uphold.com\n',
#   'pic': 'QmTFvuSJTs3PfGW5GpQ8YUnL41TV6EdZoRxVAS7Q8bWoL6',
#   'untrustedAddress': '0x95d53611fe737abc5f810a5900208242d29645df',
#   'untrustedTimestamp': 1586719707,
#   'shareID': '',
#   'parentID': ''},
#  {'info': 'Earn lots of ETH with only 0.51 ETH.',
#   'location': 'VIET NAM',
#   'realName': 'NGUYEN PHU NHO',
#   'website': 'https://nguyenphunho.github.io',
#   'avatarUrl': 'peepeth:ciFCVS92:png',
#   'backgroundUrl': 'peepeth:MQtVrsaj:png',
#   'messageToWorld': 'Earn lots of ETH with only 0.51 ETH.',
#   'untrustedTimestamp': 1586719884},
#  {'followee': '0x0c54fccd2e384b4bb6f2e405bf5cbc15a017aafb',
#   'untrustedTimestamp': 1586720500},
#  {'followee': '0x14ce500a86f1e3ace039571e657783e069643617',
#   'untrustedTimestamp': 1586720503},
#  {'followee': '0xd5d1fb2920b0f06d2fdea991e83bbe3d71956dfe',
#   'untrustedTimestamp': 1586720506},
#  {'followee': '0xe47494379c1d48ee73454c251a6395fdd4f9eb43',
#   'untrustedTimestamp': 1586720513},
#  {'followee': '0x10537001a8a4d1ef9dbf4a08d9af48ab4cc715d4',
#   'untrustedTimestamp': 1586720515},
#  {'followee': '0x51e97f164e8f2780d4fa778c5ab8cfbddea553ea',
#   'untrustedTimestamp': 1586720528},
#  {'followee': '0xf98a39456903cfde206603bdd1e1d4227dbe1243',
#   'untrustedTimestamp': 1586720528},
#  {'info': '',
#   'location': '',
#   'realName': 'Reduan',
#   'website': '',
#   'avatarUrl': '',
#   'backgroundUrl': '',
#   'messageToWorld': '',
#   'untrustedTimestamp': 1586722232,
#   'provisionalName': 'redu',
#   'address': '0x94a928f584523f6b9299770c0d825c1e4c15d231'},
#  {'type': 'peep',
#   'content': 'Earn lots of ETH with only 0.51 ETH.\n\n Website: https://nguyenphunho.github.io\n\n Dapp Sign Up: https://oneclickdapp.com/short-oxygen\n Dapp radar: https://dappradar.com/app/1843\n Dapp Review: https://dapp.review/dapp/12733\n Dapp Online: https://dapponline.io/dapp-detail/3445\n',
#   'pic': 'QmahuN2FeNXnMv7EQ4KWhQZ9WJ9DkuCdbNzXecTtJE7VE5',
#   'untrustedAddress': '0x95d53611fe737abc5f810a5900208242d29645df',
#   'untrustedTimestamp': 1586724826,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': 'The Pi is here \nPi is a new digital currency being developed by a group of Stanford PhDs. For a limited time, you can join the beta to earn Pi and help grow the network. To join Pi, follow this link https://minepi.com/ArthurMad82 and use my username (ArthurMad82) as your invitati',
#   'pics': [],
#   'untrustedAddress': '0xce6c6094bb8c8425ceb64a47410c7c074c52fcfd',
#   'untrustedTimestamp': 1576123274,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': 'You can hire some one from fiverr to help you.Join Fiverr and discover the fastest way to hire freelancers, for any online project. Thank me later!\n\nResponsePostReferralLink(directLink=https://www.fiverr.com/s2/3796e0ace1)',
#   'pics': [],
#   'untrustedAddress': '0xce6c6094bb8c8425ceb64a47410c7c074c52fcfd',
#   'untrustedTimestamp': 1576123401,
#   'shareID': '',
#   'parentID': 'QmdX27C7PXtNXDfA69YKRGXkJjE9Fgy49HLWJjKeq1RcaB'},
#  {'type': 'peep',
#   'content': 'This game once you set it up to automatically play it self will pay you Crypto over time . The higher you go the more you will gain . True story I play this game and uninstall it and forgot about it then two months later instal it again and to my surprise the Crypto I earn increa',
#   'pics': [],
#   'untrustedAddress': '0xce6c6094bb8c8425ceb64a47410c7c074c52fcfd',
#   'untrustedTimestamp': 1576145702,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': "Hey, let's play Crypto Idle Miner together, you can earn some Hora Tokens! https://idleminer.onelink.me/Irub/72e05854\n",
#   'pics': [],
#   'untrustedAddress': '0xce6c6094bb8c8425ceb64a47410c7c074c52fcfd',
#   'untrustedTimestamp': 1576158734,
#   'shareID': '',
#   'parentID': 'QmU4NRgKL2X4WfPrcUGZzKmqQLi2rPLreZXSMEN7uasUTW'},
#  {'type': 'peep',
#   'content': 'Who new you can make money by sharing your referral.\nThe door are opening for me .\n https://myadsfactory.com/main/referal/ArthurMad82',
#   'pics': [],
#   'untrustedAddress': '0xce6c6094bb8c8425ceb64a47410c7c074c52fcfd',
#   'untrustedTimestamp': 1576202648,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': 'The snow ball\nI am learning how to turn this small app and website that earn you penny and combine them together to use there referral links and have them pay for there advertising.\n\nI learn there are sight that pay for your referral link and banners and build on top of that .\n\nT',
#   'pics': [],
#   'untrustedAddress': '0xce6c6094bb8c8425ceb64a47410c7c074c52fcfd',
#   'untrustedTimestamp': 1576241590,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': 'So easy watch the video\nSo easy I can do it \nhttps://reallysimplesystem.com/dap/a/?a=5603&p=https://reallysimplesystem.com/viralfeedbackloop',
#   'pics': [],
#   'untrustedAddress': '0xce6c6094bb8c8425ceb64a47410c7c074c52fcfd',
#   'untrustedTimestamp': 1576388867,
#   'shareID': '',
#   'parentID': ''},
#  {'followee': '0x1db3439a222c519ab44bb1144fc28167b4fa6ee6',
#   'untrustedTimestamp': 1577159927},
#  {'type': 'peep',
#   'content': 'I have a question if the money go to ptp eth wallet and there a back door how would they be able to steal it. ',
#   'pics': [],
#   'untrustedAddress': '0xce6c6094bb8c8425ceb64a47410c7c074c52fcfd',
#   'untrustedTimestamp': 1577166189,
#   'shareID': '',
#   'parentID': 'QmZ2Lv8b4piu6HyoJBzC97koVhzCGm4G3nMyJU2W2dka6d'},
#  {'type': 'peep',
#   'content': 'The future of Dapp is now \nhttps://lk.million.money/a/23163/\nPlease message me if you need more help to join\n',
#   'pics': ['QmdHi4imxVHMAdHGZ7WkWs6WsNEuoEfjB4qAzJ8qATWBiW'],
#   'untrustedAddress': '0xce6c6094bb8c8425ceb64a47410c7c074c52fcfd',
#   'untrustedTimestamp': 1577636465,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': 'The future the dapp is now\nhttps://lk.million.money/a/23163/\n',
#   'pics': ['QmeiJYUvt5B4G1RZawGk4MVvZopzoHJh62P7rcCTNixiuM'],
#   'untrustedAddress': '0xce6c6094bb8c8425ceb64a47410c7c074c52fcfd',
#   'untrustedTimestamp': 1577641939,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': 'Let this Etherian co contract invaid your reality and multiply .\nhttps://lk.million.money/a/23163/\n',
#   'pics': ['QmYC8WxsTpNSJ3ipqPwzRKcN26skdbrNkgfVwJiANPDuE7'],
#   'untrustedAddress': '0xce6c6094bb8c8425ceb64a47410c7c074c52fcfd',
#   'untrustedTimestamp': 1577685881,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': 'Utility for your Ethereum wallet\nhttps://lk.million.money/a/23163/\n',
#   'pics': ['QmbJpQY7yUgYqu6sfgzuKXWRoDAP2RrHxttBgfA6c2XpLD'],
#   'untrustedAddress': '0xce6c6094bb8c8425ceb64a47410c7c074c52fcfd',
#   'untrustedTimestamp': 1577691765,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': 'Allow your ethereum to come alive\nhttps://lk.million.money/a/23163/',
#   'pics': ['Qmd2UKqEq93W1waLkvKCfAP7ZmQXpS59U9seo5WUCZ3pan'],
#   'untrustedAddress': '0xce6c6094bb8c8425ceb64a47410c7c074c52fcfd',
#   'untrustedTimestamp': 1577692401,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': 'I tip any one a 1$ if they use my cash app . Send a screenshot shot as proof and I verify if I got paid .\nHey! I’ve been using Cash App to send money and spend using the Cash Card. Try it using my code and we’ll each get $5. NQHRNXL \nhttps://cash.app/app/NQHRNXL',
#   'pics': [],
#   'untrustedAddress': '0xce6c6094bb8c8425ceb64a47410c7c074c52fcfd',
#   'untrustedTimestamp': 1586738669,
#   'shareID': '',
#   'parentID': ''},
#  {'info': 'Admin at Smart contract.',
#   'location': 'VIET NAM',
#   'realName': 'NGUYEN PHU NHO',
#   'website': 'https://nguyenphunho.github.io',
#   'avatarUrl': 'peepeth:ciFCVS92:png',
#   'backgroundUrl': 'peepeth:MQtVrsaj:png',
#   'messageToWorld': 'Earn lots of ETH with only 0.51 ETH.',
#   'untrustedTimestamp': 1586742863},
#  {'type': 'peep',
#   'content': 'Guys we are working on a MOBA type of game that pays allows people to stake cryptos and get paid to win. It is like league of legends or dota 2. There will be a tower defense alpha test run soon where you get to earn cryptos. Check it out. https://www.coba.zone',
#   'pic': '',
#   'untrustedAddress': '0x9bf3776cc7e5dcc7fd586e73dd04578c8f8fa81d',
#   'untrustedTimestamp': 1586745107,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': 'You can see it exploded just under the switch',
#   'pics': [],
#   'untrustedAddress': '0x79c1079cc754613761fc3709c3bcff898e902888',
#   'untrustedTimestamp': 1586747463,
#   'shareID': '',
#   'parentID': 'QmatTaomUS3jErFax9tJ6nRu47fCckWz1j5rgSzhwMoWn3'},
#  {'info': 'Electrician • Musician • Independent',
#   'location': 'North Carolina',
#   'realName': 'Jeremy Patrick Martin',
#   'website': 'https://JeremyPatrickMartin.crypto',
#   'avatarUrl': 'peepeth:97Q7mcbr:jpg',
#   'backgroundUrl': 'peepeth:yDWLrBM3:jpg',
#   'messageToWorld': '',
#   'untrustedTimestamp': 1586747703},
#  {'info': 'Electrician • Musician • Independent',
#   'location': 'North Carolina',
#   'realName': 'Jeremy Patrick Martin',
#   'website': 'https://JeremyPatrickMartin.com',
#   'avatarUrl': 'peepeth:97Q7mcbr:jpg',
#   'backgroundUrl': 'peepeth:yDWLrBM3:jpg',
#   'messageToWorld': '',
#   'untrustedTimestamp': 1586747786},
#  {'follower': '0x79c1079cc754613761fc3709c3bcff898e902888',
#   'followee': '0x6aa17a72ecd9a4bc058ff2ab7180679c404a7b65',
#   'untrustedTimestamp': 1586747911,
#   'signature': '0x89d2c603806637d106983fd0c0e6c9f86a5563bebd6a4b3c218e0ca0b98ce95650208e3a2441344270678dc04c4c1f2dcffcb84290c065d474050d30d33855741c'},
#  {'type': 'peep',
#   'content': "is thegraph just a collection of apis for dapps following graphql specs + a collection of nodes u can use to access the data instead of having to run your own ethereum node or use infura? \n\nhaven't rly looked into it and don't do web dev or blockhain dev for that matte",
#   'pic': '',
#   'untrustedAddress': '0x1b6a6072c8eac4ec04b171e9e665786a60d4925f',
#   'untrustedTimestamp': 1586723470,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': 'At the trailhead today.',
#   'pics': ['QmRYuWwQoLi1T4qz3vVXs7RqXP3awhoYAVuLGum2Kijzx4'],
#   'untrustedAddress': '0x9b74c8ac5d9c13836e677d0c279e7f038417724b',
#   'untrustedTimestamp': 1586749687,
#   'shareID': '',
#   'parentID': ''}]

# %%
# Out:
# 19

# %%
list(asdf.items())
# Out:
# [('k', 'b'), ('b', 'c')]

# %%
a = bst[0]

new_data = []
        
for tx in a['signedActions']:
    for action_type, data in tx.items():
        if "ipfs" in data:
            break

# %%
client_example.get_data_from_ipfs(data['ipfs'])['signedActions']
# Out:
# [{'accountUpdate': {'ipfs': 'QmSaL4cZzcnC72kqDE7wwZmPKgqLVKZfequonu8Jcszzyw',
#    'untrustedTimestamp': 1586360110}}]

# %%
def get_data_from_ipfs(ipfs_hash):
    url_to_request = f"https://ipfs.io/ipfs/{ipfs_hash}"
    return requests.get(url_to_request) \
                   .json()

# %%
def parsed_signed_actions(signed_actions):
    """recursively parses the signed actions
       
       dfs i think? lmao
    
       need to refactor this"""
    if signed_actions == []:
        return [] 
    if type(signed_actions) == dict:
        if "signedActions" in signed_actions:
            return parsed_signed_actions(signed_actions['signedActions'])
        else:
            return [signed_actions]
    for action, data in signed_actions[0].items():
        if "ipfs" in data:
            new_url = get_data_from_ipfs(data['ipfs'])
            return parsed_signed_actions(new_url) \
                   + parsed_signed_actions(signed_actions[1:])
        else:
            return [data] + parsed_signed_actions(signed_actions[1:])

# %%
b = bst[1]

# %%
# Out:
# [{'type': 'peep',
#   'content': '',
#   'pics': ['QmW9onrpw7H1NCWHwq3qZ6TrtTB8kLR4qM9VNVM8iuGHJ1'],
#   'untrustedAddress': '0x9b74c8ac5d9c13836e677d0c279e7f038417724b',
#   'untrustedTimestamp': 1586371643,
#   'shareID': '',
#   'parentID': ''},
#  {'type': 'peep',
#   'content': "So, how's the quarantine going for you guys? Well, a stream of an Xbox could be of assistance for you to relax through this time. Gonna start in two hours.",
#   'pic': '',
#   'untrustedAddress': '0x826292b6af90fcc94b4b2bb90de1b2a510341460',
#   'untrustedTimestamp': 1586373771,
#   'shareID': '',
#   'parentID': ''}]

# %%
res = []
for i in bst:
    res.append(parsed_signed_actions(i))

# %%
bst
# Out:
# [{'signedActions': [{'signedAccount': {'ipfs': 'QmWhqAktXNvoxmB8W4Sw97fYo6ZfXdXe4U6fnToCoFHGE4',
#      'untrustedTimestamp': 1586359509,
#      'address': '0x2c5c715f666f45305054e4bea8627afd40232f14',
#      'signature': '0x2050f96a73416e4a5f7b101d40024ca0b20e204ee0eef60c9ded8518aca7a8d77739a2c0fc3081394cb49af76eeb03deb16c779c0b7bdbae142f8400f979342a1b'}},
#    {'enableDelegate': {'address': '0x79c1079cc754613761fc3709c3bcff898e902888',
#      'master': '0x2c5c715f666f45305054e4bea8627afd40232f14',
#      'untrustedTimestamp': 1586359885,
#      'signature': '0x4f0949dbce0073bfbc8e9bca3107fb8776b0fed9a7e258cb721b6eeb7ea28e3f03433fce16d3db826e478bb3e0c799c95f5963ec13d4968339118c0e89230f221b',
#      'host': 'peepeth'}},
#    {'enableDelegate': {'address': '0x568209847c761181946b936fde904890bd52676b',
#      'master': '0x2c5c715f666f45305054e4bea8627afd40232f14',
#      'untrustedTimestamp': 1586359886,
#      'signature': '0xd92fd660579600f9a53d9bb1a4f8249f71cf78549a5b956daba09adb78fa74005e5ac6b871f0b9087692cada841b2b57ff72274e32ac3c37a56fc12dc10aacda1b',
#      'host': 'peepeth'}},
#    {'userSignedBatch': {'ipfs': 'QmSjY71hRBr1AHacN9zCxyLH6fdm68ZKY1aC4g9rDboZHg',
#      'address': '0x2c5c715f666f45305054e4bea8627afd40232f14',
#      'signature': '0x831bcaedfaf1ee5116a77083830ef374fd9560a7040278924914e59e6ea19bef55db161dec5c12a7481fb5461c1a4d05b34d820ab0f338415b5ebde518c9e5941c',
#      'untrustedTimestamp': 1586360219}}]},
#  {'signedActions': [{'peep': {'ipfs': 'QmbwEnEenDknxwo62G7kT3BXCmA1ZVdeSPyrRzyJEVZbAy',
#      'untrustedTimestamp': 1586371643,
#      'address': '0x9b74c8ac5d9c13836e677d0c279e7f038417724b',
#      'signature': '0xe51b45c4872a6f7a37f00523ad42da9c8d2494b0e8d25d099353cbb1e8aeb2f8188c420f22543bb95509fa39a91f50813f2a6e39472bcafcbfd241a5416cec381b'}},
#    {'peep': {'ipfs': 'QmSJxDCsF4TrxgtpvZCxiTroJGZQQWp8YUTbh3NGxbpDUk',
#      'untrustedTimestamp': 1586373779,
#      'address': '0x826292b6af90fcc94b4b2bb90de1b2a510341460',
#      'signature': '0xb96f75fba9eddf267a4a27a8dc80bdb462072719bb62027cf7cfde296e5f843918d9f0f4a7d903c7dcc171cef9fbe54e523dbd0bc93fbaaa7b2e27c0300fdac11b'}}]},
#  {'signedActions': [{'userSignedBatch': {'ipfs': 'QmPD3URPoijuTbckivHhHfQ8fpH6Cr4gYWLAoY4Jnh93h8',
#      'address': '0x06252cd1ba607d016040d273a3866f04e1e5f29d',
#      'signature': '0x3ce1679f8d59982b3bb297e3159d5f06d1c44c4d4289551f365859b04e517e7051052d87e1ff7ecc44cd971bbb8cbbcf338ff56cafa956f263ba1eade3ce17ba1b',
#      'untrustedTimestamp': 1586378002}},
#    {'peep': {'ipfs': 'QmPKafhhsr9hrktcgFwWW8gmRHFpnMecpuGpG1W184uwQa',
#      'untrustedTimestamp': 1586379607,
#      'address': '0x826292b6af90fcc94b4b2bb90de1b2a510341460',
#      'signature': '0xaaa6b946539a3f982f5d82e3e1755d53d078536e9aec8633bf78f9c5dbbda1c60f08ea0ec3924a51a14df1de66df05b2f818c1a6b848581095913b57968cea3c1b'}}]},
#  {'signedActions': [{'userSignedBatch': {'ipfs': 'QmWHYrDoN5oaFvQ5stpwAAE2BBtsMfLUY9fqrQwZP39fB9',
#      'address': '0xeaa09af8dda09f23f5d3013db052185c98f8f3c5',
#      'signature': '0xe21122b80f4481ec29acf54b073d867acf381ffc0204dab33adde41fe14eb1ba4c2109ac7d70972c52512771d1ed2e215fdfec3ba25e05cf94c8ce686d6534b11b',
#      'untrustedTimestamp': 1586391480}}]},
#  {'signedActions': [{'userSignedBatch': {'ipfs': 'QmZwLbUsu46in2UddT92wu8tqeCy37aexvM9Dx74sj9PEZ',
#      'address': '0x926e54f7a2ecc16151bb87be2bac37d8dcb637e3',
#      'signature': '0xdcd90dfd96eb66ba713f0e870428663adc86670afa3d644af349e8ebbf0901a7791c951d128d23502c1ddf2edd3cb01e5db1fb77c6d2168b42147c0eb38f94191b',
#      'untrustedTimestamp': 1586403228}}]},
#  {'signedActions': [{'userSignedBatch': {'ipfs': 'QmdvtUszMa4gh7jQAc6ep3GmVJyi1NLFM2ywARZNV9vgz8',
#      'address': '0x9bf3776cc7e5dcc7fd586e73dd04578c8f8fa81d',
#      'signature': '0x921962ca821c9e0609c028c121453a65eaf0c034f08c175ad81f4995503e6208286bb5498fd55626fb1647bfdeb4fd2ebc1ffdb0f7df9e060702a29f2e45a4621b',
#      'untrustedTimestamp': 1586407407}}]},
#  {'signedActions': [{'peep': {'ipfs': 'QmPDM2f1LZSaeiXpz44wEKgZyHQpzYjMGC3FfZZWgooxkG',
#      'untrustedTimestamp': 1586408275,
#      'address': '0x9bf3776cc7e5dcc7fd586e73dd04578c8f8fa81d',
#      'signature': '0x2172e42bf8fe22ee9a0c2214cec0913c1120c1c4ec5dbea655ac140fb1dc6b4b36d6672699a34bdbada5694cf3e7117ae9838dc69b5fdaf06941edfb88ac4f511c'}},
#    {'userSignedBatch': {'ipfs': 'QmaBD6po2JBrMDF2fcWv3ZLzuTjzzyhExtPoDbUhx7DaKP',
#      'address': '0x9bf3776cc7e5dcc7fd586e73dd04578c8f8fa81d',
#      'signature': '0x7dac0df365e176c00cab96a4a8b40656398542eebb74dc574805e5fb61e0df0f171a28f1c33ca33d819653490fd10caafa64a81f72d4e731b008f34dbd613c981b',
#      'untrustedTimestamp': 1586408356}}]},
#  {'signedActions': [{'userSignedBatch': {'ipfs': 'QmaH11ATd6PjeYdF9XiHUckZjBRnWSpEE4yaAPUWfbfmxb',
#      'address': '0x7e9318be142723a75635de754432a4a11ac42120',
#      'signature': '0x320d0b2ec248d61c6236eb69d03105c808e1bc9ac3940bcf141721a6634f28a9502d317d31acc5c2243377cde9a3044fb263dc5abe069e2e002a55468420cc171c',
#      'untrustedTimestamp': 1586411147}},
#    {'userSignedBatch': {'ipfs': 'QmS92kdqinSszAygZDJwHp7b25NtcmwCN8zUp2CeMcdvz9',
#      'address': '0x00f33c3bce1b479bc7ffacc986badced8b2d7cad',
#      'signature': '0x13820647afb24366104fb3c994eb16ba71ae0e2bc214f5b6ed4b93b593332dcc1c295cad4b9bc492e1e8fcb6b1f91f7b92625e5bea73e9d6b1030165d99729ca1b',
#      'untrustedTimestamp': 1586411170}},
#    {'userSignedBatch': {'ipfs': 'Qma2b1BFJuunK62Ah8641ziu9u8uXfzcgtdADtwHa2S9A4',
#      'address': '0xa7bd09daab3eb5ec96f04914d94c47681489d604',
#      'signature': '0x0a24b46bce3f0ae1756da42f31cd98662eae0346ebe6bdacc2373ff12f6616875a578df54c917c840b282b7698ab7c464b12f3edb30e7dddf0b1404e407026541c',
#      'untrustedTimestamp': 1586413404}}]},
#  {'signedActions': [{'userSignedBatch': {'ipfs': 'QmWkGwhcWK94W9J62ZrMF8poFzVHvZNxiJU3gE2vRN5uJc',
#      'address': '0x7e9318be142723a75635de754432a4a11ac42120',
#      'signature': '0x62186be283f673ae192002374e9dee4db6bb19e285f3a327548022faeb0d5d3f1f67135e25a70eb23c9c450934a9aab1169546e50f56d1ce033052f9f024febb1c',
#      'untrustedTimestamp': 1586413949}}]},
#  {'signedActions': [{'peep': {'ipfs': 'QmWTc1ikisxkwexbvPqKYvMX5s2oE8mEtdjBCH9bdvq6sz',
#      'untrustedTimestamp': 1586423566,
#      'address': '0x00f33c3bce1b479bc7ffacc986badced8b2d7cad',
#      'signature': '0x6d0c166946b861a2718db25e89ee05e2c47106250447272105859bfea0d0e5fc462faffe060750a380e8129999f5918ad504940c4da0cca25c74a7ce4a0019ad1b'}}]},
#  {'signedActions': [{'signedAccount': {'ipfs': 'QmdfCmeXggDJgkRER7wJenxB2Dco3EJKbxSBYaekg7sFwz',
#      'untrustedTimestamp': 1586436569,
#      'address': '0xad3e10f53ffe8a54853f648aaa4efe3460a3db5b',
#      'signature': '0x32adfb50ef0f19dd5f9b46c1a78dddb84797195eb1e5f1412e3b037249efd91729f91e1dec59d6293920881f83c23b37c6e82dd84ce21a3cba94b3ff6b89ce3f1b'}}]},
#  {'signedActions': [{'userSignedBatch': {'ipfs': 'QmYC1rAFViHneDPxR16yea9XcwBuEGrQjy4g6dp9ELj3wR',
#      'address': '0x7cdcc837b3a12ed4daf1337cb96a3fadeb443a8c',
#      'signature': '0x17c12a7034c70e84ca7567a1c5949e6bb39d881df939c126a7a6f7df98750a9c24ce6fb07a3a4f16cbdd83c8574b7312badf3623ca18db752a2c2edb4d5656431c',
#      'untrustedTimestamp': 1586445874}},
#    {'peep': {'ipfs': 'QmbotfRQ756prXtY9e7USgry7PcfVk6juFgs1Pqi599xHU',
#      'untrustedTimestamp': 1586445970,
#      'address': '0x7cdcc837b3a12ed4daf1337cb96a3fadeb443a8c',
#      'signature': '0x231b6eb873ed898266804c142ecfe8ab9f6a54b5d0bb3570ce07d716b75c343d5d198944d437f096f47db5570cd792cbd69bbe46cb396883b1d9624727a430f31c'}}]},
#  {'signedActions': [{'peep': {'ipfs': 'QmUbFFUrdu2YET9RQVKjMZn3Z9FeomtDL3F6jSUWS1VWFB',
#      'untrustedTimestamp': 1586453234,
#      'address': '0x79c1079cc754613761fc3709c3bcff898e902888',
#      'signature': '0x54305080fa2174ada802951674b6b313c7bd61aed82ac5368975eef662f8a52e06880589142ad9ac85b9bdad2855bc49c74a521925ade7ba3cb915e0b0058ba41c'}}]},
#  {'signedActions': [{'userSignedBatch': {'ipfs': 'QmNeiuBkXEm7z5YJic2L83WNXHiXAUSC51gQChJa8cfjW7',
#      'address': '0x2c5c715f666f45305054e4bea8627afd40232f14',
#      'signature': '0x602221fbe7de99b2c8f4ebae24e0a0a5283a315956a63293012112136e55f50828e495994607fe1fdaf3a7dc21f12985f8759e963604f3b038bc55e2019a13fe1c',
#      'untrustedTimestamp': 1586465388}}]},
#  {'signedActions': [{'userSignedBatch': {'ipfs': 'QmaPEP3xauwtXgWKUxqXmpd4TSHv4ypgGNu8tyqMq8qkvH',
#      'address': '0x2c5c715f666f45305054e4bea8627afd40232f14',
#      'signature': '0x862ddfa468cc61baa385e1d2d65814a15f96b0dfd2e7b0f96dcf9d0bcc70026077b4a34a4d0f426c5efad6bc0895c5a171edab849777b8770a7bd922367e11001b',
#      'untrustedTimestamp': 1586466394}},
#    {'disableDelegate': {'address': '0x79c1079cc754613761fc3709c3bcff898e902888',
#      'master': '0x2c5c715f666f45305054e4bea8627afd40232f14',
#      'untrustedTimestamp': 1586466602,
#      'signature': '0xb1597d2740d3cd699e43d923b175be2e87184225a2181e7c75edabc9aef495cd68c418bd9cd9ecdf433e5d0d0ce25ea084abc6a54a155b5917689465530734c91b'}}]},
#  {'signedActions': [{'peep': {'ipfs': 'QmeCupMtZh6fykYiD8imHPJwd3CR6cpVtJZPFkZCRHZp3j',
#      'untrustedTimestamp': 1586478662,
#      'address': '0x9b74c8ac5d9c13836e677d0c279e7f038417724b',
#      'signature': '0x3865ace75214c274d17ceca64052cbb1776bc5ae53a56b14c3e905ce77c439d5047c924f52a00e46bfc8fa9b6edb87e8e2e54254319bda43782040c1695817611c'}},
#    {'peep': {'ipfs': 'QmVokt59457LPx15U2uddtPoDWv7aw1KVA7VJg5jDWhMVZ',
#      'untrustedTimestamp': 1586478701,
#      'address': '0x9b74c8ac5d9c13836e677d0c279e7f038417724b',
#      'signature': '0xe81c1c5c6f76be751cd6df46f0acf19dd0a401e052cfa6b9cc92e1f8862995bc61a239668d79759e6d18e6184bb6a704ab7477b18f78f5ffb4d2c869e12f2ef21b'}},
#    {'peep': {'ipfs': 'QmYj5Xr7Tv3eqCxwYzgA8bum9gusC68FSLBidzDGWdYdSB',
#      'untrustedTimestamp': 1586478745,
#      'address': '0x9b74c8ac5d9c13836e677d0c279e7f038417724b',
#      'signature': '0x4a25199765a371778a4fe19154969249a30ac4835be51442a2b7f8b4af7065877ed001c665de41d75c46edfc85472c8155619e4f5ca6c87152e9865ab72a7d011b'}},
#    {'peep': {'ipfs': 'QmWU5Uj1wsQaNdrxm7F9E8FXWyndAN1VCRGF34XvNXeaPX',
#      'untrustedTimestamp': 1586478772,
#      'address': '0x9b74c8ac5d9c13836e677d0c279e7f038417724b',
#      'signature': '0x27d4046758deea52e8f70f7c18b5b8c959a45a4f2d3ba3e50592a4607057d2452941e8dfdf3afcd4cd3cfc4ecd14d46f11808c145fa255f7c95ab77d4206cfb81b'}}]},
#  {'signedActions': [{'userSignedBatch': {'ipfs': 'QmamwXtxZXrugwjgczKHERkZJFwdwJzpaNS4VRGXuTHvKj',
#      'address': '0x04f353b356fce4f72e31302fe0f7b7169303861f',
#      'signature': '0x1574235728105be4c2db3d0efbc13fec58d74ef723d6e33becd71000aa68388056367a2147efaae315f6462885b830248cd3b0eec3c53ed7221e93d54722d36a1b',
#      'untrustedTimestamp': 1586483043}},
#    {'userSignedBatch': {'ipfs': 'QmVNTJwDyeAB2i3x6uo7wGb83vY6yKy1UhVriTnag8rPjy',
#      'address': '0x04f353b356fce4f72e31302fe0f7b7169303861f',
#      'signature': '0x77ed9eada89b57ec224a598e4c579880546d7f5fdb032e27ea00cb1bc70be48c6e89d410d6ec7ecc38a793cd02acfd3f1ba074ba084a0bed837350ac2bfd73721c',
#      'untrustedTimestamp': 1586483127}}]}]

# %%
res
# Out:
# [[{'info': 'Electrician • Musician • Independent',
#    'location': 'NC',
#    'realName': 'Jeremy Patrick Martin',
#    'website': 'https://JeremyPatrickMartin.com',
#    'avatarUrl': 'peepeth:97Q7mcbr:jpg',
#    'backgroundUrl': 'peepeth:yDWLrBM3:jpg',
#    'messageToWorld': '',
#    'untrustedTimestamp': 1586359473,
#    'provisionalName': 'JeremyPatMartin',
#    'address': '0x2c5c715f666f45305054e4bea8627afd40232f14'},
#   {'address': '0x79c1079cc754613761fc3709c3bcff898e902888',
#    'master': '0x2c5c715f666f45305054e4bea8627afd40232f14',
#    'untrustedTimestamp': 1586359885,
#    'signature': '0x4f0949dbce0073bfbc8e9bca3107fb8776b0fed9a7e258cb721b6eeb7ea28e3f03433fce16d3db826e478bb3e0c799c95f5963ec13d4968339118c0e89230f221b',
#    'host': 'peepeth'},
#   {'address': '0x568209847c761181946b936fde904890bd52676b',
#    'master': '0x2c5c715f666f45305054e4bea8627afd40232f14',
#    'untrustedTimestamp': 1586359886,
#    'signature': '0xd92fd660579600f9a53d9bb1a4f8249f71cf78549a5b956daba09adb78fa74005e5ac6b871f0b9087692cada841b2b57ff72274e32ac3c37a56fc12dc10aacda1b',
#    'host': 'peepeth'},
#   {'info': 'Electrician • Musician • Independent',
#    'location': 'North Carolina',
#    'realName': 'Jeremy Patrick Martin',
#    'website': 'https://JeremyPatrickMartin.com',
#    'avatarUrl': 'peepeth:97Q7mcbr:jpg',
#    'backgroundUrl': 'peepeth:yDWLrBM3:jpg',
#    'messageToWorld': '',
#    'untrustedTimestamp': 1586360110}],
#  [{'type': 'peep',
#    'content': '',
#    'pics': ['QmW9onrpw7H1NCWHwq3qZ6TrtTB8kLR4qM9VNVM8iuGHJ1'],
#    'untrustedAddress': '0x9b74c8ac5d9c13836e677d0c279e7f038417724b',
#    'untrustedTimestamp': 1586371643,
#    'shareID': '',
#    'parentID': ''},
#   {'type': 'peep',
#    'content': "So, how's the quarantine going for you guys? Well, a stream of an Xbox could be of assistance for you to relax through this time. Gonna start in two hours.",
#    'pic': '',
#    'untrustedAddress': '0x826292b6af90fcc94b4b2bb90de1b2a510341460',
#    'untrustedTimestamp': 1586373771,
#    'shareID': '',
#    'parentID': ''}],
#  [{'type': 'peep',
#    'content': '‘Idiot’ New Zealand Health Minister Demoted After Driving Family to Beach in Lockdown \nhttps://www.bloomberg.com/news/articles/2020-04-06/minister-demoted-rugby-star-slammed-for-n-z-lockdown-breach \n\n',
#    'pics': [],
#    'untrustedAddress': '0x06252cd1ba607d016040d273a3866f04e1e5f29d',
#    'untrustedTimestamp': 1586269468,
#    'shareID': '',
#    'parentID': ''},
#   {'type': 'peep',
#    'content': 'Before coronavirus, UK government promoted ‘business opportunities’ in China’s wet markets \nhttps://www.dailymaverick.co.za/article/2020-04-04-exclusive-before-coronavirus-uk-government-promoted-business-opportunities-in-chinas-wet-markets/ \n',
#    'pics': ['QmP9KhJzKQHKoK9Dg4i3NocEj1LBonAuD5B97SUNpGu6cQ'],
#    'untrustedAddress': '0x06252cd1ba607d016040d273a3866f04e1e5f29d',
#    'untrustedTimestamp': 1586377984,
#    'shareID': '',
#    'parentID': ''},
#   {'type': 'peep',
#    'content': "Let's go back to 2001.\n\nhttps://dlive.tv/HipHopPhantom\nhttps://vimm.tv/@HipHopPhantom",
#    'pic': 'QmZkQG9Kh9LXWyykwM9Vup8B62LuGQsQ63T5wZ28WhRPkq',
#    'untrustedAddress': '0x826292b6af90fcc94b4b2bb90de1b2a510341460',
#    'untrustedTimestamp': 1586379603,
#    'shareID': '',
#    'parentID': ''}],
#  [{'type': 'peep',
#    'content': 'One not only speaketh, but liveth more than speaketh itself.',
#    'pics': [],
#    'untrustedAddress': '0xeaa09af8dda09f23f5d3013db052185c98f8f3c5',
#    'untrustedTimestamp': 1586391470,
#    'shareID': '',
#    'parentID': ''}],
#  [{'type': 'peep',
#    'content': 'https://www.youtube.com/watch?v=TKEXV5XMCiI',
#    'pics': [],
#    'untrustedAddress': '0x926e54f7a2ecc16151bb87be2bac37d8dcb637e3',
#    'untrustedTimestamp': 1586403134,
#    'shareID': '',
#    'parentID': ''},
#   {'type': 'peep',
#    'content': 'BITCOIN % at CRITICAL LEVEL!! Are ALTCOINS About to EXPLODE?! Satoshi’s Identity [Theory] https://www.youtube.com/watch?v=TKEXV5XMCiI',
#    'pics': [],
#    'untrustedAddress': '0x926e54f7a2ecc16151bb87be2bac37d8dcb637e3',
#    'untrustedTimestamp': 1586403214,
#    'shareID': '',
#    'parentID': ''}],
#  [{'type': 'peep',
#    'content': 'Agreed brother!',
#    'pics': [],
#    'untrustedAddress': '0x9bf3776cc7e5dcc7fd586e73dd04578c8f8fa81d',
#    'untrustedTimestamp': 1586407400,
#    'shareID': 'QmemJKCandAAfeo5FTKVRqxXD6baFnJFzTXNXqA4t5tsGD',
#    'parentID': ''}],
#  [{'type': 'peep',
#    'content': 'A company in HK is working on a game like league of legends or dota that allows people to stake and get paid. Do you think this will affect the blockchain gaming industry positively? check out https://coba.zone',
#    'pic': '',
#    'untrustedAddress': '0x9bf3776cc7e5dcc7fd586e73dd04578c8f8fa81d',
#    'untrustedTimestamp': 1586408270,
#    'shareID': '',
#    'parentID': ''},
#   {'type': 'peep',
#    'content': "I have build a browser with a dAppstore. It's like appstore for BC applications or sites. Let me know if you are interested in listing. ",
#    'pics': [],
#    'untrustedAddress': '0x9bf3776cc7e5dcc7fd586e73dd04578c8f8fa81d',
#    'untrustedTimestamp': 1586407964,
#    'shareID': '',
#    'parentID': 'QmSAr4mbqzrZSyBPAqbwvzbWF8naGgSg9gWhPXRqiCPFzP'},
#   {'messageID': 'QmdpVr29VPawJ8pg13jzbCKsUGxdNmsQ99YiE2nuDDvCcB',
#    'untrustedTimestamp': 1586408350}],
#  [{'type': 'peep',
#    'content': 'どこの真ん中',
#    'pics': ['Qmb5Z1fbJBFv1hjexCb1J1yHuJX9ZkDM6NCgq62VN2kKcs'],
#    'untrustedAddress': '0x7e9318be142723a75635de754432a4a11ac42120',
#    'untrustedTimestamp': 1586411140,
#    'shareID': '',
#    'parentID': ''},
#   {'type': 'peep',
#    'content': 'Have you guys tried out the Newdex OTC service? Learn more about it in my article at publisher0x:\n\nhttps://www.publish0x.com/blockchainenthusiast/newdex-otc-service-xklqrl',
#    'pics': ['QmXmHZ3L7SSxw8nZKCEgzo91nVaf88kizRcuXU5jqsR4o8'],
#    'untrustedAddress': '0x00f33c3bce1b479bc7ffacc986badced8b2d7cad',
#    'untrustedTimestamp': 1586411134,
#    'shareID': '',
#    'parentID': ''},
#   {'type': 'peep',
#    'content': '🙏',
#    'pics': [],
#    'untrustedAddress': '0xa7bd09daab3eb5ec96f04914d94c47681489d604',
#    'untrustedTimestamp': 1586413388,
#    'shareID': '',
#    'parentID': 'QmPGezHEccC4iawjX8VpfiFKo4jqV7w3pzW8ibyuN144Kh'}],
#  [{'type': 'peep',
#    'content': '魂は不本意です',
#    'pics': ['QmW83dTQtHzYnxeSJv3tCinh3RL6Tqbq4EcHNYWcH7d8Rj'],
#    'untrustedAddress': '0x7e9318be142723a75635de754432a4a11ac42120',
#    'untrustedTimestamp': 1586413941,
#    'shareID': '',
#    'parentID': ''}],
#  [{'type': 'peep',
#    'content': 'What are Instant Liquidity Exchanges and How to Make a Profit from them?\n\nhttps://www.publish0x.com/blockchainenthusiast/what-are-instant-liquidity-exchanges-and-how-to-make-a-profi-xlmrnr',
#    'pic': 'QmfFjibDMZcaHzm4CNMLCBkFwPPckbaqjZYi2pebi3ZRdY',
#    'untrustedAddress': '0x00f33c3bce1b479bc7ffacc986badced8b2d7cad',
#    'untrustedTimestamp': 1586423560,
#    'shareID': '',
#    'parentID': ''}],
#  [{'info': '',
#    'location': '',
#    'realName': '',
#    'website': '',
#    'avatarUrl': '',
#    'backgroundUrl': '',
#    'messageToWorld': '',
#    'untrustedTimestamp': 1586436553,
#    'provisionalName': 'FlatEric',
#    'address': '0xad3e10f53ffe8a54853f648aaa4efe3460a3db5b'}],
#  [{'type': 'peep',
#    'content': 'The realtime multiplayer blockchain game Cryptoman is back, but faster and funnier than ever before, connecting players from different chains. Register and receive a 60 TRX starter bonus!\nhttps://cryptoman.app',
#    'pics': [],
#    'untrustedAddress': '0x7cdcc837b3a12ed4daf1337cb96a3fadeb443a8c',
#    'untrustedTimestamp': 1572526914,
#    'shareID': '',
#    'parentID': ''},
#   {'type': 'peep',
#    'content': 'We are excited to anounce a new cryptoman tournament! \nIt is not one but 3 with a total price money of 1500 USD in Ebk! The tournaments will take place for 3 weeks with the first qualification starting on 11.04.2020 lasting for one week. https://cryptoman.app',
#    'pic': 'QmTTS3eBdmZddUxxHBQsT2kBajnfmm8PKagrVVYfB3KRxY',
#    'untrustedAddress': '0x7cdcc837b3a12ed4daf1337cb96a3fadeb443a8c',
#    'untrustedTimestamp': 1586445993,
#    'shareID': '',
#    'parentID': ''}],
#  [{'type': 'peep',
#    'content': 'Unboxing my Pixel4xl\nhttps://youtu.be/5lb1bmkLLwg\n\n',
#    'pics': [],
#    'untrustedAddress': '0x79c1079cc754613761fc3709c3bcff898e902888',
#    'untrustedTimestamp': 1586453234,
#    'shareID': '',
#    'parentID': ''}],
#  [{'type': 'peep',
#    'content': 'How-to: eSIM\nhttps://youtu.be/4as12HMWFZQ',
#    'pics': [],
#    'untrustedAddress': '0x2c5c715f666f45305054e4bea8627afd40232f14',
#    'untrustedTimestamp': 1586465359,
#    'shareID': '',
#    'parentID': ''}],
#  [{'followee': '0xf678da8081cc0bedd27062865c924e77b3963c6b',
#    'untrustedTimestamp': 1586465864},
#   {'followee': '0xec3281124d4c2fca8a88e3076c1e7749cfecb7f2',
#    'untrustedTimestamp': 1586466072},
#   {'followee': '0x13ebd3443fa5575f0eb173e323d8419f7452cfb1',
#    'untrustedTimestamp': 1586466182},
#   {'followee': '0xb2b043fa603e9a80beae2897c3a58f91668f8c7b',
#    'untrustedTimestamp': 1586466246},
#   {'address': '0x79c1079cc754613761fc3709c3bcff898e902888',
#    'master': '0x2c5c715f666f45305054e4bea8627afd40232f14',
#    'untrustedTimestamp': 1586466602,
#    'signature': '0xb1597d2740d3cd699e43d923b175be2e87184225a2181e7c75edabc9aef495cd68c418bd9cd9ecdf433e5d0d0ce25ea084abc6a54a155b5917689465530734c91b'}],
#  [{'type': 'peep',
#    'content': '🦶 ',
#    'pics': ['QmNWCcpjqXgYxhqRAL4kaHQRSxLmBnz2rarMNQqgQxKZ6P'],
#    'untrustedAddress': '0x9b74c8ac5d9c13836e677d0c279e7f038417724b',
#    'untrustedTimestamp': 1586478662,
#    'shareID': '',
#    'parentID': ''},
#   {'type': 'peep',
#    'content': '',
#    'pics': ['QmQThgrFzUo8m6AJHvPyEQ5CbCn7DyrK2CdocntRgoq39y'],
#    'untrustedAddress': '0x9b74c8ac5d9c13836e677d0c279e7f038417724b',
#    'untrustedTimestamp': 1586478701,
#    'shareID': '',
#    'parentID': ''},
#   {'type': 'peep',
#    'content': '',
#    'pics': ['QmdoNuY9L2b4sKcrsdVffvE8aseWprtMXmKHuvvJTAT6Wd'],
#    'untrustedAddress': '0x9b74c8ac5d9c13836e677d0c279e7f038417724b',
#    'untrustedTimestamp': 1586478745,
#    'shareID': '',
#    'parentID': ''},
#   {'type': 'peep',
#    'content': 'Barefoot today',
#    'pics': ['QmScjfiyKw7fvMfv9nBo4XucmuND7t2Q1x5BjSnbkoSMXM'],
#    'untrustedAddress': '0x9b74c8ac5d9c13836e677d0c279e7f038417724b',
#    'untrustedTimestamp': 1586478772,
#    'shareID': '',
#    'parentID': ''}],
#  [{'followee': '0x30755d3e65c0cf46c35b72d11e52d941c5fc3a3e',
#    'untrustedTimestamp': 1575735750},
#   {'type': 'peep',
#    'content': 'That’s pretty',
#    'pics': [],
#    'untrustedAddress': '0x04f353b356fce4f72e31302fe0f7b7169303861f',
#    'untrustedTimestamp': 1575735783,
#    'shareID': '',
#    'parentID': 'QmcQPzbTnmWi4G8eQEShPVmhZgL9JAj7A1MoTfBfaxe5Ck'},
#   {'type': 'peep',
#    'content': 'I am so bored being stuck inside sucks!! Is this virus even real!!',
#    'pics': [],
#    'untrustedAddress': '0x04f353b356fce4f72e31302fe0f7b7169303861f',
#    'untrustedTimestamp': 1586483097,
#    'shareID': '',
#    'parentID': ''},
#   {'messageID': 'QmWU5Uj1wsQaNdrxm7F9E8FXWyndAN1VCRGF34XvNXeaPX',
#    'untrustedTimestamp': 1586483112}]]
